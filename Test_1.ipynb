# %%
import os
import numpy as np
import pandas as pd
import torch 
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, TensorDataset
from sklearn.datasets import fetch_openml
import torchvision.transforms as transforms
import torch.optim as optim
import cv2

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = np.array(img)
    print(npimg.shape)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5) , (0.5,  0.5, 0.5))])

# %%
class Sattelites_Dataset(Dataset):
    
    def __init__(self, base_root, transform = None):
        self.__base_root = base_root
        self.__img_file = os.listdir(self.__base_root)
        self.transform = transform
    
    def __getitem__(self, idx):
        path = self.__img_file[idx]
        img = cv2.imread(os.path.join(self.__base_root,path))
        if self.transform:
            img = self.transform(img)
        return img, 1
    
    
    def __len__(self):
        return len(self.__img_file)

# %%
class Generator(nn.Module):
    
    def __init__(self,layer_size):
        pass

# %%
dataset = Sattelites_Dataset("data", transform = transform)
dataloader = DataLoader(dataset, batch_size = 1000, shuffle = False)

# %%
# Out:
# torch.Size([3, 256, 256])

# %%
print(images.shape)
imshow(images[0])
# Out:
# torch.Size([64, 3, 256, 256])
# (3, 256, 256)
